# %% [markdown]
# # Exclusion lmits for dark-matter nucleon scattering

# %%
from numpy import *
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.patheffects as pe
from PlotFuncs import *

plt.style.use('sty.mplstyle')

fig, ax = plt.subplots()

fpath = '../data/limits/Nucleon/SI/'

rot_45 = 18

# Plot limits
PlotBound(ax,fpath+'LZ_2024.txt',edgecolor='darkgreen',textcolor='darkgreen',facecolor=[0.0, 0.62, 0.38],label=r'{\bf LZ}',rotation=rot_45,label_pos=[2000,1.8e-47])
PlotBound(ax,fpath+'XENONnT_2025_Combined.txt',edgecolor='teal',textcolor='teal',facealpha=0,label=r'{\bf XENONnT}',rotation=rot_45,label_pos=[1000,5.0e-46])
PlotBound(ax,fpath+'XENONnT_2025_Combined.txt',edgecolor='teal',textcolor='teal',facecolor=col_alpha('teal',0.5),zorder=-1)
PlotBound(ax,fpath+'XENON1T-Migdal.txt',edgecolor='teal',textcolor='teal',linestyle=':',facealpha=0,label=r'\begin{center} XENON1T \linebreak (Migdal)\end{center}',fontsize=15,rotation=-38,label_pos=[0.45,0.5e-38],path_effects=None)
PlotBound(ax,fpath+'PandaX_2024_Combined.txt',edgecolor='navy',textcolor='navy',facealpha=0,label=r'{\bf PandaX}',rotation=rot_45,label_pos=[1500,1.0e-46])
PlotBound(ax,fpath+'PandaX_2024_Combined.txt',edgecolor='navy',textcolor='navy',facecolor=col_alpha('navy',0.5),zorder=-1.1)
PlotBound(ax,fpath+'CRESST.txt',edgecolor=[0.8, 0.25, 0.33],textcolor=[0.8, 0.25, 0.33],facecolor=[0.74, 0.56, 0.56],zorder=-1,label=r'{\bf CRESST}',rotation=-41,label_pos=[0.9,1.5e-38],fontsize=22)
PlotBound(ax,fpath+'DarkSide-50_2022.txt',edgecolor='seagreen',textcolor='seagreen',facecolor='seagreen',facealpha=0.0,label=r'{\bf DarkSide}',rotation=-65,label_pos=[1.1,1.5e-41],fontsize=20)
PlotBound(ax,fpath+'DarkSide-50_2022.txt',edgecolor='seagreen',textcolor='seagreen',facecolor='seagreen',facealpha=0.5,zorder=-3)
PlotBound(ax,fpath+'EDELWEISS.txt',edgecolor='orange',textcolor='orange',facealpha=0,label=r'{\bf EDELWEISS}',rotation=-45,label_pos=[8,3e-42],fontsize=17)
PlotBound(ax,fpath+'DEAP-3600.txt',edgecolor='#4ff09d',textcolor='#4ff09d',facealpha=0,label=r'{\bf DEAP-3600}',rotation=rot_45-1,label_pos=[1000,1.9e-44])
PlotBound(ax,fpath+'PICO60.txt',edgecolor=[0.5, 0.0, 0.13],textcolor=[0.5, 0.0, 0.13],facealpha=0,label=r'{\bf PICO60}',rotation=rot_45-8,label_pos=[40,1e-43])
PlotBound(ax,fpath+'COSINE-100.txt',edgecolor='gold',textcolor='gold',facealpha=0,label=r'{\bf COSINE-100}',rotation=rot_45-2,label_pos=[300,1.5e-42])

#PlotBound(ax,fpath+'LUX.txt',edgecolor='crimson',textcolor='crimson',facealpha=0,label='LUX',rotation=rot_45,label_pos=[300,1e-45])
PlotBound(ax,fpath+'NEWS-G.txt',edgecolor='m',textcolor='m',facealpha=0,label=r'{\bf NEWS-G}',rotation=6,label_pos=[17,0.35e-38])


# neutrino fog
PlotBound(ax,'../data/fog/Nucleon/SI/nuFog_n2_Xe.txt',y2=0,label=r'\begin{center} {\bf Neutrino fog \linebreak (Xe)}\end{center}',label_pos=[0.3,7e-47],fontsize=29,rotation=0,facecolor='#a7b9d6',lw=0,textcolor='#a7b9d6',facealpha=0.5)


# DAMA
PlotBound(ax,fpath+'DAMA1.txt',y2=nan,edgecolor='darkslategray',textcolor='darkslategray',facecolor='forestgreen',label=r'{\bf DAMA}',label_pos=[22,5e-40])
PlotBound(ax,fpath+'DAMA2.txt',y2=nan,edgecolor='darkslategray',textcolor='darkslategray',facecolor='forestgreen')
plt.arrow(0.485, 0.735, -0.012, -0.018, transform=fig.transFigure,figure=fig,length_includes_head=False,lw=1,head_width=0.007, head_length=0.014, overhang=0.13,edgecolor='darkslategray',facecolor='darkslategray',clip_on=True,path_effects=line_background(2,'k'))
plt.arrow(0.55, 0.73, 0.012, -0.055, transform=fig.transFigure,figure=fig,length_includes_head=False,lw=1,head_width=0.007, head_length=0.014, overhang=0.13,edgecolor='darkslategray',facecolor='darkslategray',clip_on=True,path_effects=line_background(2,'k'))


# Models
# PlotBound(ax, '../data/models/Nucleon/SI/NMSSM_Scan.txt',y2=nan,lw=1,path_effects=None,textcolor='gray',edgecolor='dimgray',facecolor='gray',facealpha=0.5,label=r'\begin{center} {\bf NMSSM}\end{center}',rotation=17,label_pos=[190,1.5e-48],text_path_effects=None,hatch='/')

PlotBound(ax,'SI_optimo_DAMA.txt',edgecolor='black',textcolor='black',facealpha=0,label=r'{\bf ANAIS-112 - QF DAMA}',rotation=rot_45-2,label_pos=[200,7e-44])

PlotBound(ax,'SI_optimo_Tamara.txt',edgecolor='blue',textcolor='blue',facealpha=0,label=r'{\bf ANAIS-112 - QF ANAIS}',rotation=rot_45-2,label_pos=[200,7e-42])

# Finishing touches
ax.set_yscale('log')
ax.set_xscale('log')
ax.set_xlim([0.1,1e4])
ax.set_ylim([5e-50,1e-37])
ax.set_xlabel('Dark matter mass [GeV/$c^2$]')
ax.set_ylabel(r'SI DM-nucleon cross section [cm$^{2}$]')
locmaj = matplotlib.ticker.LogLocator(base=10.0, subs=(1.0, ), numticks=50)
locmin = matplotlib.ticker.LogLocator(base=10.0, subs=arange(2, 10)*.1,numticks=100)
ax.yaxis.set_major_locator(locmaj)
ax.yaxis.set_minor_locator(locmin)



MySaveFig(fig,'Nucleon_SI')


#PlotBound(ax,fpath+'Projections/SuperCDMS.txt',edgecolor='orange',textcolor='orange',facealpha=0,label=r'\begin{center} SuperCDMS\end{center}',linestyle='--',rotation=0,fontsize=20,label_pos=[0.15,1.05e-43],end_x=-10,path_effects=None,text_path_effects=None)
#PlotBound(ax,fpath+'Projections/DarkSide-20k.txt',edgecolor='seagreen',textcolor='seagreen',facealpha=0,label=r'\begin{center} DarkSide-20k \end{center}',linestyle='--',rotation=rot_45-5,fontsize=20,label_pos=[200,2.0e-48],path_effects=None,text_path_effects=None)
##PlotBound(ax,fpath+'Projections/LXe_200ty_90excl.txt',edgecolor='gray',textcolor='gray',facealpha=0,label=r'\begin{center} XLZD \end{center}',linestyle='--',rotation=rot_45,fontsize=20,label_pos=[200,0.3e-48],path_effects=None,text_path_effects=None)
#PlotBound(ax,fpath+'Projections/NEWS-G-Projection.txt',edgecolor='m',textcolor='m',facealpha=0,label=r'\begin{center} NEWS-G \end{center}',linestyle='--',rotation=-60,fontsize=20,label_pos=[0.168,5e-39],path_effects=None,text_path_effects=None)
#PlotBound(ax,fpath+'Projections/SBC.txt',edgecolor=[0.5, 0.0, 0.13],textcolor=[0.5, 0.0, 0.13],facealpha=0,label=r'\begin{center} SBC \end{center}',linestyle='--',rotation=-17,fontsize=20,label_pos=[1.8,4e-44],path_effects=None,text_path_effects=None,end_x=-60)
#PlotBound(ax,fpath+'Projections/DarkSPHERE.txt',edgecolor='m',textcolor='m',facealpha=0,label=r'\begin{center} DarkSPHERE \end{center}',linestyle='--',rotation=-38,fontsize=17,label_pos=[0.125,1.4e-41],path_effects=None,text_path_effects=None)
#PlotBound(ax,fpath+'Projections/CDEX.txt',edgecolor='royalblue',textcolor='royalblue',facealpha=0,label=r'\begin{center} CDEX \end{center}',linestyle='--',rotation=0,fontsize=17,label_pos=[2,5e-45],path_effects=None,text_path_effects=None)

MySaveFig(fig,'Nucleon_SI_with_Projections')

# %%
from numpy import *
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.patheffects as pe
from PlotFuncs import *

plt.style.use('sty.mplstyle')

fig, ax = plt.subplots()

fpath = '../data/limits/Nucleon/SDp/'

rot_45 = 16

# Plot limits
PlotBound(ax,fpath+'LZ_2024.txt',edgecolor='darkgreen',textcolor='darkgreen',facecolor=[0.0, 0.62, 0.38],label=r'{\bf LZ}',rotation=rot_45,label_pos=[2000,1.0e-40])
PlotBound(ax,fpath+'PICASSO.txt',edgecolor='#ad512f',textcolor='#ad512f',facealpha=0,label=r'{\bf PICASSO}',rotation=rot_45-1,label_pos=[100,0.35e-37])
PlotBound(ax,fpath+'PICASSO.txt',edgecolor='#ad512f',textcolor='#ad512f',facecolor=col_alpha('#ad512f',0.5),zorder=-10)
PlotBound(ax,fpath+'PICO60.txt',edgecolor=[0.5, 0.0, 0.13],textcolor=[0.5, 0.0, 0.13],facealpha=0,label=r'{\bf PICO60}',rotation=-26,label_pos=[4,0.7e-40])
PlotBound(ax,fpath+'PICO60.txt',edgecolor=[0.5, 0.0, 0.13],textcolor=[0.5, 0.0, 0.13],facecolor=col_alpha([0.5, 0.0, 0.13],0.5),zorder=-11)
PlotBound(ax,fpath+'CRESST.txt',edgecolor=[0.8, 0.25, 0.33],textcolor=[0.8, 0.25, 0.33],facealpha=0,label=r'{\bf CRESST}',rotation=0,label_pos=[0.5,0.1e-33],fontsize=22)
PlotBound(ax,fpath+'CRESST.txt',edgecolor=[0.8, 0.25, 0.33],textcolor=[0.8, 0.25, 0.33],facecolor=col_alpha([0.8, 0.25, 0.33],0.5),zorder=-11)
PlotBound(ax,fpath+'XENONnT_2025.txt',edgecolor='teal',textcolor='teal',facealpha=0,label=r'{\bf XENONnT}',rotation=rot_45-1,label_pos=[500,15e-40])
PlotBound(ax,fpath+'PandaX.txt',edgecolor='navy',textcolor='navy',facealpha=0,label=r'{\bf PandaX}',rotation=0,label_pos=[16,6.0e-40])
PlotBound(ax,fpath+'COUPP.txt',edgecolor='orange',textcolor='orange',facealpha=0,label=r'{\bf COUPP}',rotation=rot_45-1,label_pos=[800,33e-39])
PlotBound(ax,fpath+'NEWS-G.txt',edgecolor='m',textcolor='m',facealpha=0,label=r'{\bf NEWS-G}',rotation=-10,label_pos=[0.25,0.2e-34],fontsize=22)
PlotBound(ax,fpath+'NEWS-G.txt',edgecolor='m',textcolor='m',facecolor=col_alpha('m',0.5),zorder=-12)

# PlotBound(ax,fpath+'ATLAS.txt',edgecolor='crimson',textcolor='crimson',facealpha=0,lw=2,linestyle='--',label='ATLAS',rotation=rot_45,label_pos=[300,1e-45],zorder=-10)
# PlotBound(ax,fpath+'IceCube-tt.txt',edgecolor='crimson',textcolor='crimson',facealpha=0,lw=2,linestyle='--',label='ATLAS',rotation=rot_45,label_pos=[300,1e-45],zorder=-10)
# PlotBound(ax,fpath+'SuperK-tt.txt',edgecolor='crimson',textcolor='crimson',facealpha=0,lw=2,linestyle='--',label='ATLAS',rotation=rot_45,label_pos=[300,1e-45],zorder=-10)
#PlotBound(ax,fpath+'AllLimits-2024.txt',edgecolor='gray',textcolor='gray',facecolor='gray')


# neutrino fog
PlotBound(ax,'../data/fog/Nucleon/SDp/nuFog_n2_F.txt',y2=0,label=r'\begin{center} {\bf Neutrino fog \linebreak ($^{19}$F)}\end{center}',label_pos=[0.3,4e-44],fontsize=29,rotation=0,facecolor='#a7b9d6',lw=0,textcolor='#a7b9d6',facealpha=0.5)

# Finishing touches
ax.set_yscale('log')
ax.set_xscale('log')
ax.set_xlim([0.1,1e4])
ax.set_ylim([5e-46,1e-32])
ax.set_xlabel('Dark matter mass [GeV/$c^2$]')
ax.set_ylabel(r'SD DM-proton cross section [cm$^{2}$]')
locmaj = matplotlib.ticker.LogLocator(base=10.0, subs=(1.0, ), numticks=50)
locmin = matplotlib.ticker.LogLocator(base=10.0, subs=arange(2, 10)*.1,numticks=100)
ax.yaxis.set_major_locator(locmaj)
ax.yaxis.set_minor_locator(locmin)


plt.gcf().text(0.78, 0.82, r'\begin{center}Spin-dependent \linebreak (proton)\end{center}',ha='center',color='black',multialignment='center',
            bbox=dict(facecolor='w', linewidth=1.5,
                        edgecolor='black', boxstyle='round,pad=0.2'))

MySaveFig(fig,'Nucleon_SDp')

PlotBound(ax,fpath+'Projections/DarkSPHERE.txt',edgecolor='m',textcolor='m',facealpha=0,label=r'\begin{center} DarkSPHERE \end{center}',linestyle='--',rotation=20,fontsize=17,label_pos=[0.55,2.3e-41],path_effects=None,text_path_effects=None)

MySaveFig(fig,'Nucleon_SDp_with_Projections')

# %%
from numpy import *
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.patheffects as pe
from PlotFuncs import *

plt.style.use('sty.mplstyle')

fig, ax = plt.subplots()

fpath = '../data/limits/Nucleon/SDn/'

rot_45 = 16

# Plot limits
PlotBound(ax,fpath+'LZ_2024.txt',edgecolor='darkgreen',textcolor='darkgreen',facecolor=[0.0, 0.62, 0.38],label=r'{\bf LZ}',rotation=rot_45,label_pos=[2000,1.5e-41])

PlotBound(ax,fpath+'XENONnT_2025_Combined.txt',edgecolor='teal',textcolor='teal',facealpha=0,label=r'{\bf XENONnT}',rotation=rot_45-1,label_pos=[300,0.25e-40])
PlotBound(ax,fpath+'XENONnT_2025_Combined.txt',edgecolor='teal',textcolor='teal',facecolor=col_alpha('teal',0.5),zorder=-10)

PlotBound(ax,fpath+'PandaX.txt',edgecolor='navy',textcolor='navy',facealpha=0,label=r'{\bf PandaX}',rotation=rot_45-3,label_pos=[100,0.125e-41])
PlotBound(ax,fpath+'CDMS.txt',edgecolor='gold',textcolor='gold',facealpha=0,label=r'{\bf CDMS}',rotation=rot_45,label_pos=[800,1.8e-37])
PlotBound(ax,fpath+'CRESST.txt',edgecolor=[0.8, 0.25, 0.33],textcolor=[0.8, 0.25, 0.33],facealpha=0,label=r'{\bf CRESST}',rotation=0,label_pos=[0.47,1.5e-33],fontsize=21)
PlotBound(ax,fpath+'CRESST.txt',edgecolor=[0.8, 0.25, 0.33],textcolor=[0.8, 0.25, 0.33],facecolor=col_alpha([0.8, 0.25, 0.33],0.5),zorder=-11)
PlotBound(ax,fpath+'CDMSlite.txt',edgecolor='gold',textcolor='gold',facealpha=0,label=r'{\bf CDMSlite}',rotation=5,label_pos=[12.5,2e-36],fontsize=22)
PlotBound(ax,fpath+'CDMSlite.txt',edgecolor='gold',textcolor='gold',facecolor=col_alpha('#7da832',0.5),zorder=-11)
PlotBound(ax,fpath+'XENON1T-Migdal.txt',edgecolor='teal',textcolor='teal',linestyle=':',facealpha=0,label=r'\begin{center} XENON1T \linebreak (Migdal)\end{center}',fontsize=15,rotation=-38,label_pos=[0.7,0.2e-33],path_effects=None,zorder=-12)



# neutrino fog
PlotBound(ax,'../data/fog/Nucleon/SDn/nuFog_n2_Xe.txt',y2=0,label=r'\begin{center} {\bf Neutrino fog \linebreak (Xe)}\end{center}',label_pos=[0.3,7e-42],fontsize=29,rotation=0,facecolor='#a7b9d6',lw=0,textcolor='#a7b9d6',facealpha=0.5)

# Finishing touches
ax.set_yscale('log')
ax.set_xscale('log')
ax.set_xlim([0.1,1e4])
ax.set_ylim([5e-46,1e-32])
ax.set_xlabel('Dark matter mass [GeV/$c^2$]')
ax.set_ylabel(r'SD DM-neutron cross section [cm$^{2}$]')
locmaj = matplotlib.ticker.LogLocator(base=10.0, subs=(1.0, ), numticks=50)
locmin = matplotlib.ticker.LogLocator(base=10.0, subs=arange(2, 10)*.1,numticks=100)
ax.yaxis.set_major_locator(locmaj)
ax.yaxis.set_minor_locator(locmin)



plt.gcf().text(0.78, 0.82, r'\begin{center}Spin-dependent \linebreak (neutron)\end{center}',ha='center',color='black',multialignment='center',
            bbox=dict(facecolor='w', linewidth=1.5,
                        edgecolor='black', boxstyle='round,pad=0.2'))

MySaveFig(fig,'Nucleon_SDn')

PlotBound(ax,fpath+'Projections/DarkSPHERE.txt',edgecolor='m',textcolor='m',facealpha=0,label=r'\begin{center} DarkSPHERE \end{center}',linestyle='--',rotation=-15,fontsize=17,label_pos=[0.55,0.8e-37],path_effects=None,text_path_effects=None)

MySaveFig(fig,'Nucleon_SDn_with_Projections')

# %%
# XENONnT
fpath = '../data/limits/Nucleon/SI/'
file_list = ['XENONnT_2024_Combined','XENONnT_2025']
CreateEnvelope(fpath,file_list,'XENONnT_2025_Combined',1e-1,1e4,nm=1000,header='Envelope of XENON limits as of 2025 \n Mass [GeV] \t sigma_n_SD [cm^2]')

fpath = '../data/limits/Nucleon/SDn/'
file_list = ['XENONnT_2024_Combined','XENONnT_2025']
CreateEnvelope(fpath,file_list,'XENONnT_2025_Combined',1e-1,1e4,nm=1000,header='Envelope of XENON limits as of 2025 \n Mass [GeV] \t sigma_n_SD [cm^2]')

fpath = '../data/limits/Nucleon/SDp/'
file_list = ['XENONnT_2024','XENONnT_2025']
CreateEnvelope(fpath,file_list,'XENONnT_2025_Combined',1e-1,1e4,nm=1000,header='Envelope of XENON limits as of 2025 \n Mass [GeV] \t sigma_p_SD [cm^2]')



# All limits
fpath = '../data/limits/Nucleon/SI/'
file_list = ['NEWS-G','DarkSide-50_2022','CRESST','PandaX_2024_Combined','XENONnT_2025_Combined','LZ_2024']
CreateEnvelope(fpath,file_list,'AllLimits-2024',1e-1,1e4,nm=1000,header='Envelope of best limits as of 2024 \n Mass [GeV] \t sigma_p_SI [cm^2]')

fpath = '../data/limits/Nucleon/SDp/'
file_list = ['LZ_2024','PICASSO','PICO60','XENONnT_2025_Combined']
CreateEnvelope(fpath,file_list,'AllLimits-2024',1e-1,1e4,nm=1000,header='Envelope of best limits as of 2024 \n Mass [GeV] \t sigma_p_SD [cm^2]')

fpath = '../data/limits/Nucleon/SDn/'
file_list = ['CRESST','XENONnT_2025_Combined','CDMSlite','LZ_2024']
CreateEnvelope(fpath,file_list,'AllLimits-2024',1e-1,1e4,nm=1000,header='Envelope of best limits as of 2024 \n Mass [GeV] \t sigma_n_SD [cm^2]')

# %%
from numpy import *
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.patheffects as pe
from PlotFuncs import *

plt.style.use('sty.mplstyle')

fig, ax = plt.subplots()

fpath = '../data/limits/Nucleon/SI/'

rot_45 = 18

# Plot limits
PlotBound(ax,fpath+'AllLimits-2024.txt',edgecolor='darkgreen',textcolor='darkgreen',facecolor=col_alpha('seagreen',0.4),zorder=-1,facealpha=1)


PlotBound(ax,fpath+'LUX.txt',edgecolor='darkgreen',textcolor='darkgreen',facecolor='seagreen',zorder=-1,facealpha=0)

PlotBound(ax,fpath+'ZEPLIN-III.txt',edgecolor='darkgreen',textcolor='darkgreen',facecolor='seagreen',zorder=-1,facealpha=0)

# neutrino fog
PlotBound(ax,'../data/fog/Nucleon/SI/nuFog_n2_Xe.txt',y2=0,label_pos=[0.3,7e-47],fontsize=29,rotation=0,facecolor='gray',lw=10,edgecolor='gray',textcolor='gray',facealpha=0.0)



# Models
# PlotBound(ax, '../data/models/Nucleon/SI/NMSSM_Scan.txt',y2=nan,lw=1,path_effects=None,textcolor='gray',edgecolor='dimgray',facecolor='gray',facealpha=0.5,label=r'\begin{center} {\bf NMSSM}\end{center}',rotation=17,label_pos=[190,1.5e-48],text_path_effects=None,hatch='/')


# Finishing touches
ax.set_yscale('log')
ax.set_xscale('log')
ax.set_xlim([0.5,1e4])
ax.set_ylim([5e-50,1e-41])
# ax.set_xlabel('Dark matter mass')
# ax.set_ylabel(r'Dark matter interaction strength')
locmaj = matplotlib.ticker.LogLocator(base=10.0, subs=(1.0, ), numticks=50)
locmin = matplotlib.ticker.LogLocator(base=10.0, subs=arange(2, 10)*.1,numticks=100)
ax.yaxis.set_major_locator(locmaj)
ax.yaxis.set_minor_locator(locmin)
ax.set_xticklabels([])
ax.set_yticklabels([])


#MySaveFig(fig,'Nucleon_SI')


#PlotBound(ax,fpath+'Projections/SuperCDMS.txt',edgecolor='crimson',textcolor='orange',facealpha=0,linestyle='--',rotation=0,fontsize=20,label_pos=[0.15,1.05e-43],end_x=-10,path_effects=None,text_path_effects=None)
#PlotBound(ax,fpath+'Projections/DarkSide-20k.txt',edgecolor='crimson',textcolor='seagreen',facealpha=0,linestyle='--',rotation=rot_45-5,fontsize=20,label_pos=[200,2.0e-48],path_effects=None,text_path_effects=None)
PlotBound(ax,fpath+'Projections/LXe_200ty_90excl.txt',edgecolor='crimson',textcolor='gray',facealpha=0.1,linestyle='--',rotation=rot_45,fontsize=20,label_pos=[200,0.3e-48],path_effects=None,text_path_effects=None,start_x=2,lw=4,facecolor='r',zorder=-10)
#PlotBound(ax,fpath+'Projections/NEWS-G-Projection.txt',edgecolor='crimson',textcolor='m',facealpha=0,linestyle='--',rotation=-60,fontsize=20,label_pos=[0.168,5e-39],path_effects=None,text_path_effects=None)
#PlotBound(ax,fpath+'Projections/SBC.txt',edgecolor='crimson',textcolor=[0.5, 0.0, 0.13],facealpha=0,linestyle='--',rotation=-17,fontsize=20,label_pos=[1.8,4e-44],path_effects=None,text_path_effects=None,end_x=-60)
#PlotBound(ax,fpath+'Projections/DarkSPHERE.txt',edgecolor='crimson',textcolor='m',facealpha=0,linestyle='--',rotation=-38,fontsize=17,label_pos=[0.125,1.4e-41],path_effects=None,text_path_effects=None)


dat = loadtxt(fpath+'CYGNUS10-timeline.txt')

plt.plot(dat[0,100:],dat[6,100:],'--',color='crimson',lw=4)
plt.fill_between(dat[0,100:],dat[6,100:],color='crimson',zorder=-100,alpha=0.1,y2=1)


MySaveFig(fig,'Nucleon_SI_with_Projections_Bare')
